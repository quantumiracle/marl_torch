# %% [markdown]
# ## Exploitability test

# %%
import numpy as np
fname='20210618_0438.log'  # pong
file = open(fname, 'r')
lines = file.read().splitlines()
print('log indices: ', lines[2])
score_l, length_l = [], []
for l in lines:
    if "Final score" in l:
        length_l.append(int(l.split('episode length: ')[-1]))
        score_l.append(float(l.split(',')[0].split('Final score: ')[-1]))
        print(l)
print(score_l, length_l)
# Out:
# log indices:  [80, 120, 340, 460, 480, 500, 520, 540, 560, 640, 660, 680, 700, 720, 740, 760, 800, 820, 840, 860, 880, 900, 1000, 1020, 1040, 1060, 1080, 1100, 1120, 1140, 1180, 1200, 1220, 1260, 1280, 1300, 1320, 1340, 1360, 1380, 1400, 1420, 1440, 1460, 1480, 1500, 1520, 1560, 1580, 1600, 1620, 1640, 1660, 1680, 1700, 1720, 1740, 1760, 1780, 1800, 1820, 1840, 1860, 1880, 1900, 1920, 1940, 1960, 1980, 2000, 2020, 2040, 2060, 2080, 2100, 2120, 2140, 2160, 2180, 2200, 2220, 2240, 2260, 2280, 2300, 2320, 2340, 2360, 2380, 2400, 2420, 2440, 2460, 2480, 2500, 2520, 2540, 2560, 2600, 2620, 2640, 2660, 2680, 2700, 2720, 2740, 2760, 2780, 2800, 2820, 2840, 2860, 2880, 2900, 2920, 2940, 2960, 2980, 3000, 3020, 3040, 3060, 3080, 3100, 3120, 3140, 3160, 3180, 3200, 3220, 3240, 3260, 3280, 3300, 3340, 3360, 3380, 3400, 3420, 3440, 3460, 3480, 3500, 3520, 3540, 3560, 3580, 3600, 3620, 3640, 3660, 3680, 3700, 3720, 3740, 3760, 3780, 3800, 3820, 3840, 3860, 3880, 3900, 3920, 3940, 3960, 3980, 4000
# ...

# %%
import matplotlib.pyplot as plt
plt.plot(score_l)

# %%
plt.plot(length_l)

# %%
import numpy as np
fname='20210618_0440.log'  # boxing
file = open(fname, 'r')
lines = file.read().splitlines()
print('log indices: ', lines[2])
score_l, length_l = [], []
for l in lines:
    if "Final score" in l:
        length_l.append(int(l.split('episode length: ')[-1]))
        score_l.append(float(l.split(',')[0].split('Final score: ')[-1]))
        print(l)
print(score_l, length_l)
# Out:
# log indices:  [3, 6, 20, 60, 80, 440, 540, 560, 1000, 1020, 1080, 1100, 1120, 1140, 1160, 1180, 1200, 1260, 1280, 1300, 1320, 1340, 1360, 1380, 1740, 1760, 1780, 1800, 1820, 1840, 1860, 1880, 1900, 1920, 1960, 1980, 2000, 2020, 2040, 4200, 4220, 4300, 4320, 4620, 5060]
# Final score: -0.75, episode length: 1784
# Final score: 4.9, episode length: 1784
# Final score: 0.0, episode length: 1784
# Final score: -2.1, episode length: 1784
# Final score: -4.65, episode length: 1784
# Final score: -5.9, episode length: 1784
# Final score: -4.95, episode length: 1784
# Final score: -6.45, episode length: 1784
# Final score: -3.5, episode length: 1784
# Final score: -0.8, episode length: 1784
# Final score: -4.05, episode length: 1784
# Final score: -7.45, episode length: 1784
# Final score: -0.4, episode length: 1784
# Final score: -2.4, episode length: 1784
# Final score: 0.95, episode length: 1784
# Final score: -7.4, episode length: 1784
# Final score: -4.3, episode length: 1784
# ...

# %%
import matplotlib.pyplot as plt
plt.plot(score_l)

# %%
plt.plot(length_l)

# %%
import numpy as np
fname='20210621_0203.log'  # boxing, noisy opponent
file = open(fname, 'r')
lines = file.read().splitlines()
print('log indices: ',  lines[2])
score_l, length_l = [], []
for l in lines:
    if "Final score" in l:
        length_l.append(int(l.split('episode length: ')[-1]))
        score_l.append(float(l.split(',')[0].split('Final score: ')[-1]))
        print(l)
print(score_l, length_l)
# Out:
# log indices:  [1000, 3000, 4000, 5000, 6000, 7000, 8000, 9000, 10000, 11000, 12000, 13000, 14000, 15000, 16000, 17000, 18000, 19000, 20000, 21000, 22000, 23000, 24000, 25000, 26000, 27000, 28000, 29000, 30000, 31000, 32000, 33000, 34000, 35000, 36000, 37000, 38000, 39000, 40000, 41000, 42000, 43000, 44000, 45000, 46000, 47000, 50000, 52000, 53000, 54000, 55000, 56000, 57000]
# Final score: 20.75, episode length: 1766
# Final score: 75.7, episode length: 829
# Final score: 10.9, episode length: 1713
# Final score: 84.3, episode length: 1194
# Final score: 59.9, episode length: 1055
# Final score: 75.45, episode length: 553
# Final score: 82.8, episode length: 502
# Final score: 78.05, episode length: 720
# Final score: 66.55, episode length: 500
# Final score: 48.35, episode length: 700
# Final score: 87.4, episode length: 427
# Final score: 19.15, episode length: 644
# Final score: 51.0, episode length: 558
# Final score: 93.45, episode length: 351
# ...

# %%
import matplotlib.pyplot as plt
plt.plot(score_l)

# %%
plt.plot(length_l)

# %%
import numpy as np
fname='20210623_2349.log'  # pong, noisy opponent
file = open(fname, 'r')
lines = file.read().splitlines()
print('log indices: ',  lines[2])
score_l, length_l = [], []
for l in lines:
    if "Final score" in l:
        length_l.append(int(l.split('episode length: ')[-1]))
        score_l.append(float(l.split(',')[0].split('Final score: ')[-1]))
        print(l)
print(score_l, length_l)
# Out:
# log indices:  [80, 120, 280, 320, 360, 380, 400, 420, 2180, 2200, 2220, 2240, 2260, 2280, 2300, 2320, 2340, 2360, 2380, 2400, 2420, 2440, 2480, 2500, 2520, 2540, 2560, 2580, 2600, 2620, 2640, 2660, 2680, 2700, 2720, 2740, 2760, 2780, 2800, 2820, 2840, 2860, 2880, 2900, 2920, 2940, 2960, 2980, 3000, 3020, 3040, 3060, 3080, 3100, 3120, 3140, 3160, 3180, 3200, 3220, 3240, 3260, 3280, 3300, 3320, 3340, 3360, 3380, 3400, 3420, 3440, 3460, 3480, 3520, 3540, 3560, 3580, 3600, 3620, 3640, 3660, 3680, 3700, 3720, 3740, 3760, 3780, 3800, 3820, 3840, 3860, 3880, 3900, 3920, 3940, 3960, 3980, 4000, 4020, 4040, 4100, 4120, 4140, 4160, 4180, 4200, 4220, 4240, 4260, 4280, 4300, 4320, 4340, 4360, 4380, 4400, 4420, 4440, 4460, 4480, 4500, 4520, 4540, 4560, 4580, 4600, 4620, 4640, 4660, 4680, 4700, 4720, 4740, 4760, 4780, 4800, 4820, 4840, 4860, 4880, 4900, 4920, 4940, 4960, 4980, 5000, 5020, 5040, 5060, 5080, 5100, 5120, 5140, 5160, 5180, 5200, 5220, 5240, 5260, 5280, 5300, 5320, 5340, 5360, 5380, 54
# ...

# %%
import matplotlib.pyplot as plt
plt.plot(score_l)

# %%
plt.plot(length_l)

# %%
'Ab'.lower()
# Out:
# 'ab'
