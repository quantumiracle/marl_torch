# %%
path='noise/'
files = ! ls $path
print(files)
# Out:
# ['10000mappo_single_1_policy', '10000mappo_single_1_value', '1000mappo_single_1_policy', '1000mappo_single_1_value', '10020mappo_single_1_policy', '10020mappo_single_1_value', '10040mappo_single_1_policy', '10040mappo_single_1_value', '10060mappo_single_1_policy', '10060mappo_single_1_value', '10080mappo_single_1_policy', '10080mappo_single_1_value', '10100mappo_single_1_policy', '10100mappo_single_1_value', '10120mappo_single_1_policy', '10120mappo_single_1_value', '10140mappo_single_1_policy', '10140mappo_single_1_value', '10160mappo_single_1_policy', '10160mappo_single_1_value', '10180mappo_single_1_policy', '10180mappo_single_1_value', '10200mappo_single_1_policy', '10200mappo_single_1_value', '1020mappo_single_1_policy', '1020mappo_single_1_value', '10220mappo_single_1_policy', '10220mappo_single_1_value', '10240mappo_single_1_policy', '10240mappo_single_1_value', '10260mappo_single_1_policy', '10260mappo_single_1_value', '10280mappo_single_1_policy', '10280mappo_single_1_value'
# ...

# %%
for f in files:
    f_idx = f.split('mappo')[0]
    if int(f_idx)%1000 == 0:
        file_name = path+ f_idx + "mappo_single_1_policy"
        dest_path = "noise_select/" + f_idx + "mappo_single_1_policy"
        ! cp -r $file_name $dest_path
        file_name = path+ f_idx + "mappo_single_1_value"
        dest_path = "noise_select/" + f_idx + "mappo_single_1_value"
        ! cp -r $file_name $dest_path
        print(f_idx)
# Out:
# 10000
# 10000
# 1000
# 1000
# 11000
# 11000
# 12000
# 12000
# 13000
# 13000
# 14000
# 14000
# 15000
# 15000
# 16000
# 16000
# 17000
# 17000
# 18000
# 18000
# 19000
# 19000
# 20000
# 20000
# 21000
# 21000
# 22000
# 22000
# 23000
# 23000
# 24000
# 24000
# 25000
# 25000
# 26000
# 26000
# 27000
# 27000
# 28000
# 28000
# 29000
# 29000
# 30000
# 30000
# 3000
# 3000
# 31000
# 31000
# 32000
# 32000
# 33000
# 33000
# 34000
# 34000
# 35000
# 35000
# 36000
# 36000
# 37000
# 37000
# 38000
# 38000
# 39000
# 39000
# 40000
# 40000
# 4000
# 4000
# 41000
# 41000
# 42000
# 42000
# 43000
# 43000
# 44000
# 44000
# 45000
# 45000
# 46000
# 46000
# 47000
# 47000
# 50000
# 50000
# 5000
# 5000
# 52000
# 52000
# 53000
# 53000
# 54000
# 54000
# 55000
# 55000
# 56000
# 56000
# 57000
# 57000
# 6000
# 6000
# 7000
# 7000
# 8000
# 8000
# 9000
# 9000

# %%
! cp -r 3mappo_single_1_policy 3mappo_single_1_policy_2
